# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X = df.drop('Outcome',axis = 1)
y = df['Outcome']

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 77/77 [==============================] - 3s 3ms/step - loss: 4.3667 - accuracy: 0.5169
# Epoch 2/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9718 - accuracy: 0.6146
# Epoch 3/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7672 - accuracy: 0.6094
# Epoch 4/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7436 - accuracy: 0.6354
# Epoch 5/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7149 - accuracy: 0.6693
# Epoch 6/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6814 - accuracy: 0.6836
# Epoch 7/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6698 - accuracy: 0.6888
# Epoch 8/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6555 - accuracy: 0.6823
# Epoch 9/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6580 - accuracy: 0.6888
# Epoch 10/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6953
# Epoch 11/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6151 - accuracy: 0.7109
# Epoch 12/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6366 - accuracy: 0.6927
# Epoch 13/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6140 - accuracy: 0.7031
# Epoch 14/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6249 - accuracy: 0.6888
# Epoch 15/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.7044
# Epoch 16/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6142 - accuracy: 0.6953
# Epoch 17/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6171 - accuracy: 0.7070
# Epoch 18/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.6953
# Epoch 19/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5853 - accuracy: 0.7161
# Epoch 20/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6178 - accuracy: 0.7044
# Epoch 21/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5902 - accuracy: 0.7096
# Epoch 22/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5952 - accuracy: 0.6927
# Epoch 23/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5741 - accuracy: 0.7174
# Epoch 24/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5886 - accuracy: 0.7122
# Epoch 25/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6043 - accuracy: 0.7083
# Epoch 26/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.6979
# Epoch 27/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5755 - accuracy: 0.7096
# Epoch 28/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5655 - accuracy: 0.7357
# Epoch 29/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7188
# Epoch 30/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5766 - accuracy: 0.7253
# Epoch 31/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5682 - accuracy: 0.7135
# Epoch 32/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5658 - accuracy: 0.7201
# Epoch 33/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5675 - accuracy: 0.7344
# Epoch 34/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.7109
# Epoch 35/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5648 - accuracy: 0.7240
# Epoch 36/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5912 - accuracy: 0.7031
# Epoch 37/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5555 - accuracy: 0.7214
# Epoch 38/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5712 - accuracy: 0.7070
# Epoch 39/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5563 - accuracy: 0.7305
# Epoch 40/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5636 - accuracy: 0.7292
# Epoch 41/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5418 - accuracy: 0.7331
# Epoch 42/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5629 - accuracy: 0.7292
# Epoch 43/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7422
# Epoch 44/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5540 - accuracy: 0.7357
# Epoch 45/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.7240
# Epoch 46/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5620 - accuracy: 0.7279
# Epoch 47/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5624 - accuracy: 0.7044
# Epoch 48/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5507 - accuracy: 0.7279
# Epoch 49/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.7357
# Epoch 50/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5522 - accuracy: 0.7005
# Epoch 51/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5353 - accuracy: 0.7318
# Epoch 52/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5365 - accuracy: 0.7344
# Epoch 53/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7266
# Epoch 54/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.7383
# Epoch 55/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7513
# Epoch 56/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.7331
# Epoch 57/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5403 - accuracy: 0.7240
# Epoch 58/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7240
# Epoch 59/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5449 - accuracy: 0.7253
# Epoch 60/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5259 - accuracy: 0.7383
# Epoch 61/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5530 - accuracy: 0.7240
# Epoch 62/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5363 - accuracy: 0.7357
# Epoch 63/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.7487
# Epoch 64/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.7448
# Epoch 65/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5362 - accuracy: 0.7253
# Epoch 66/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5422 - accuracy: 0.7383
# Epoch 67/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5326 - accuracy: 0.7448
# Epoch 68/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.7370
# Epoch 69/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.7344
# Epoch 70/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.7279
# Epoch 71/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5355 - accuracy: 0.7448
# Epoch 72/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.7305
# Epoch 73/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.7448
# Epoch 74/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5276 - accuracy: 0.7318
# Epoch 75/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5155 - accuracy: 0.7539
# Epoch 76/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.7253
# Epoch 77/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5138 - accuracy: 0.7318
# Epoch 78/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5245 - accuracy: 0.7487
# Epoch 79/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5174 - accuracy: 0.7435
# Epoch 80/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.7253
# Epoch 81/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.7487
# Epoch 82/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5296 - accuracy: 0.7591
# Epoch 83/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5485 - accuracy: 0.7383
# Epoch 84/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5183 - accuracy: 0.7526
# Epoch 85/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.7500
# Epoch 86/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5213 - accuracy: 0.7474
# Epoch 87/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7487
# Epoch 88/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5070 - accuracy: 0.7487
# Epoch 89/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5150 - accuracy: 0.7344
# Epoch 90/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5209 - accuracy: 0.7344
# Epoch 91/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5366 - accuracy: 0.7474
# Epoch 92/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5144 - accuracy: 0.7396
# Epoch 93/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5132 - accuracy: 0.7422
# Epoch 94/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5145 - accuracy: 0.7461
# Epoch 95/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.7435
# Epoch 96/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5089 - accuracy: 0.7630
# Epoch 97/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7734
# Epoch 98/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5197 - accuracy: 0.7266
# Epoch 99/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5110 - accuracy: 0.7448
# Epoch 100/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7565
# Epoch 101/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5136 - accuracy: 0.7396
# Epoch 102/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5170 - accuracy: 0.7318
# Epoch 103/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.7539
# Epoch 104/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.7396
# Epoch 105/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7461
# Epoch 106/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.7487
# Epoch 107/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.7591
# Epoch 108/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7487
# Epoch 109/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5135 - accuracy: 0.7578
# Epoch 110/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5003 - accuracy: 0.7578
# Epoch 111/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4975 - accuracy: 0.7513
# Epoch 112/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5047 - accuracy: 0.7500
# Epoch 113/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7526
# Epoch 114/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.7474
# Epoch 115/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.7591
# Epoch 116/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5070 - accuracy: 0.7487
# Epoch 117/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4918 - accuracy: 0.7539
# Epoch 118/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7552
# Epoch 119/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7643
# Epoch 120/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7513
# Epoch 121/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.7500
# Epoch 122/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5079 - accuracy: 0.7435
# Epoch 123/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5012 - accuracy: 0.7617
# Epoch 124/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.7474
# Epoch 125/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.7578
# Epoch 126/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4910 - accuracy: 0.7799
# Epoch 127/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4876 - accuracy: 0.7500
# Epoch 128/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.7383
# Epoch 129/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.7435
# Epoch 130/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4844 - accuracy: 0.7708
# Epoch 131/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4928 - accuracy: 0.7552
# Epoch 132/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5073 - accuracy: 0.7474
# Epoch 133/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4977 - accuracy: 0.7409
# Epoch 134/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.7617
# Epoch 135/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5002 - accuracy: 0.7578
# Epoch 136/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4997 - accuracy: 0.7487
# Epoch 137/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4991 - accuracy: 0.7565
# Epoch 138/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4875 - accuracy: 0.7669
# Epoch 139/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.7617
# Epoch 140/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.7292
# Epoch 141/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4997 - accuracy: 0.7552
# Epoch 142/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.7617
# Epoch 143/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4875 - accuracy: 0.7591
# Epoch 144/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4904 - accuracy: 0.7500
# Epoch 145/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.7604
# Epoch 146/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4887 - accuracy: 0.7565
# Epoch 147/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.7526
# Epoch 148/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4819 - accuracy: 0.7552
# Epoch 149/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.7604
# Epoch 150/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.7630
# Epoch 151/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4880 - accuracy: 0.7500
# Epoch 152/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.7500
# Epoch 153/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4929 - accuracy: 0.7396
# Epoch 154/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7526
# Epoch 155/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4798 - accuracy: 0.7682
# Epoch 156/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4945 - accuracy: 0.7604
# Epoch 157/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4940 - accuracy: 0.7630
# Epoch 158/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.7487
# Epoch 159/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5008 - accuracy: 0.7695
# Epoch 160/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4948 - accuracy: 0.7604
# Epoch 161/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4850 - accuracy: 0.7591
# Epoch 162/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4860 - accuracy: 0.7656
# Epoch 163/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.7669
# Epoch 164/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4870 - accuracy: 0.7591
# Epoch 165/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7604
# Epoch 166/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.7552
# Epoch 167/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.7461
# Epoch 168/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4959 - accuracy: 0.7604
# Epoch 169/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4805 - accuracy: 0.7643
# Epoch 170/200
# 77/77 [==============================] - 0s 4ms/step - loss: 0.4836 - accuracy: 0.7669
# Epoch 171/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4847 - accuracy: 0.7591
# Epoch 172/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4913 - accuracy: 0.7656
# Epoch 173/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4815 - accuracy: 0.7604
# Epoch 174/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4911 - accuracy: 0.7513
# Epoch 175/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.7799
# Epoch 176/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.7643
# Epoch 177/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4788 - accuracy: 0.7526
# Epoch 178/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4930 - accuracy: 0.7721
# Epoch 179/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.7578
# Epoch 180/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4909 - accuracy: 0.7552
# Epoch 181/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.7786
# Epoch 182/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.7695
# Epoch 183/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4895 - accuracy: 0.7591
# Epoch 184/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.7604
# Epoch 185/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.7630
# Epoch 186/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4825 - accuracy: 0.7513
# Epoch 187/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4830 - accuracy: 0.7604
# Epoch 188/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4769 - accuracy: 0.7617
# Epoch 189/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4833 - accuracy: 0.7487
# Epoch 190/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.7604
# Epoch 191/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5042 - accuracy: 0.7474
# Epoch 192/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4818 - accuracy: 0.7578
# Epoch 193/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.7513
# Epoch 194/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4796 - accuracy: 0.7617
# Epoch 195/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4827 - accuracy: 0.7539
# Epoch 196/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7695
# Epoch 197/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7630
# Epoch 198/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4900 - accuracy: 0.7604
# Epoch 199/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7643
# Epoch 200/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.7487

# %%
scores = model.evaluate(X, y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.7695
#
# accuracy: 76.95%

# %%
# !pip install ann_visualizer
# Out:
# Collecting ann_visualizer
# WARNING: You are using pip version 22.0.3; however, version 22.3 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
#   Downloading ann_visualizer-2.5.tar.gz (4.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: ann_visualizer
#   Building wheel for ann_visualizer (setup.py): started
#   Building wheel for ann_visualizer (setup.py): finished with status 'done'
#   Created wheel for ann_visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4168 sha256=db8c5fbffa8497cf877248f4e66fd8a82c56136875e01660e8f81db862e0da8d
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\4b\ef\77\9b8c4ae2f9a11de19957b80bc5c684accd99114bb8dc6b374c
# Successfully built ann_visualizer
# Installing collected packages: ann_visualizer
# Successfully installed ann_visualizer-2.5

# %%
from ann_visualizer.visualize import ann_viz;

# %%
ann_viz(model, title="Neural Network")

# ann_viz(model, view=True, filename="network.gv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      84         else:
# ---> 85             proc = subprocess.run(cmd, **kwargs)
#      86     except OSError as e:
#
# ~\AppData\Local\Programs\Python\Python38\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#
# ~\AppData\Local\Programs\Python\Python38\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ~\AppData\Local\Programs\Python\Python38\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1306             try:
# -> 1307                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1232/3836472178.py in <module>
# ----> 1 ann_viz(model, title="Neural Network")
#       2
#       3 # ann_viz(model, view=True, filename="network.gv")
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ann_visualizer\visualize.py in ann_viz(model, view, filename, title)
#     204         g.edge_attr.update(arrowhead="none", color="#707070");
#     205         if view == True:
# --> 206             g.view();
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     159                               category=category)
#     160
# --> 161             return func(*args, **kwargs)
#     162
#     163         return wrapper
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\rendering.py in view(self, filename, directory, cleanup, quiet, quiet_view)
#     180             and no way to retrieve the application's exit status.
#     181         """
# --> 182         return self.render(filename=filename, directory=directory, view=True,
#     183                            cleanup=cleanup, quiet=quiet, quiet_view=quiet_view)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     159                               category=category)
#     160
# --> 161             return func(*args, **kwargs)
#     162
#     163         return wrapper
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\rendering.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     117         args.append(filepath)
#     118
# --> 119         rendered = self._render(*args, **kwargs)
#     120
#     121         if cleanup:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     159                               category=category)
#     160
# --> 161             return func(*args, **kwargs)
#     162
#     163         return wrapper
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\backend\rendering.py in render(engine, format, filepath, renderer, formatter, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     315     cmd += args
#     316
# --> 317     execute.run_check(cmd,
#     318                       cwd=filepath.parent if filepath.parent.parts else None,
#     319                       quiet=quiet,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      86     except OSError as e:
#      87         if e.errno == errno.ENOENT:
# ---> 88             raise ExecutableNotFound(cmd) from e
#      89         raise
#      90
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (0.19)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\admin\appdata\local\programs\python\python38\lib\site-packages (22.0.3)Note: you may need to restart the kernel to use updated packages.
# Collecting pip
#   Downloading pip-22.3-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 335.5 kB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.3
#     Uninstalling pip-22.0.3:
#       Successfully uninstalled pip-22.0.3
# Successfully installed pip-22.3
