# %%
import pandas as pd

# %%
df = pd.read_excel("Yahoo Ticker Symbols.xlsx",index_col =0)

# %%
df
# Out:
#                                              Unnamed: 1 Unnamed: 2  \
# Yahoo Stock Tickers
# http://investexcel.net                              NaN        NaN
# NaN                                                 NaN        NaN
# Ticker                                             Name   Exchange
# TIF                                       Tiffany & Co.        NYQ
# RGDX                             Response Genetics, Inc        NCM
# ...                                                 ...        ...
# 0J1Z.L                                              NaN        NaN
# CIU.L                                              CAPE        LSE
# TSLF                    THL Credit Senior Loan Fund Com        NYQ
# VLLX                               Valley Republic Bank        PNK
# APA                                        Apache Corp.        NYQ
#
#                                              Unnamed: 3      Unnamed: 4  \
# Yahoo Stock Tickers
# ...
