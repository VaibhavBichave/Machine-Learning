# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
l=[]
ll=[]
for i in range(100):
    l.append(i)
    ll.append(i**3)
dict={
    "area":l,
    "price":ll
}
df=pd.DataFrame(dict)
df
# Out:
#     area   price
# 0      0       0
# 1      1       1
# 2      2       8
# 3      3      27
# 4      4      64
# ..   ...     ...
# 95    95  857375
# 96    96  884736
# 97    97  912673
# 98    98  941192
# 99    99  970299
#
# [100 rows x 2 columns]

# %%
from sklearn import linear_model

# %%
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Linear Model")
plt.scatter(df.area,df.price,color="b")

# %%
ndf=df.drop("price", axis =1)

# %%
ndf
# Out:
#     area
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
#
# [100 rows x 1 columns]

# %%
price=df.price

# %%
price
# Out:
# 0          0
# 1          1
# 2          8
# 3         27
# 4         64
#        ...
# 95    857375
# 96    884736
# 97    912673
# 98    941192
# 99    970299
# Name: price, Length: 100, dtype: int64

# %%
lreg=linear_model.LinearRegression()

# %%
lreg.fit(ndf,price)
# Out:
# LinearRegression()

# %%
lreg.predict([[330]])
# Out:
# array([2727562.2])

# %%
lreg.coef_
# Out:
# array([8850.4])

# %%
lreg.intercept_
# Out:
# -193069.80000000005

# %%
x=[8,7,2,4,6,18,19]
y=[67,78,45,56,89,342,400]

# %%
plt.scatter(ndf,price,label="actual")
plt.scatter(ndf,lreg.predict(ndf),label="predicted")
plt.title("cubic function")
plt.legend();

# %%
# Random Forest regression model
from sklearn.ensemble import RandomForestRegressor

# instantiate the model
forest = RandomForestRegressor(max_depth=9)

# fit the model 
forest.fit(ndf,price)
# Out:
# RandomForestRegressor(max_depth=9)

# %%
forest.score(ndf,price)
# Out:
# 0.9998680402696111

# %%
plt.scatter(ndf,price,label="actual")
plt.scatter(ndf,forest.predict(ndf),label="predicted")
plt.title("cubic function")
plt.legend();

# %%
plt.scatter(lreg.predict(ndf),price)

# %%
plt.scatter(ndf,price)

# %%
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1516a20b26b1> in <module>
# ----> 1 plt.scatter()
#
# NameError: name 'plt' is not defined

# %%
import numpy as np

# %%
import pandas as pd

# %%
import  matplotlib.pyplot as plt

# %%
pf= pd.read_csv("Automobile_data.csv")

# %%
pf
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data=pf

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data[data["normalized-losses"]=="?"]
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            3                 ?    alfa-romero       gas        std
# 2            1                 ?    alfa-romero       gas        std
# 5            2                 ?           audi       gas        std
# 7            1                 ?           audi       gas        std
# 9            0                 ?           audi       gas      turbo
# 14           1                 ?            bmw       gas        std
# 15           0                 ?            bmw       gas        std
# 16           0                 ?            bmw       gas        std
# 17           0                 ?            bmw       gas        std
# 43           0                 ?          isuzu       gas        std
# 44           1                 ?          isuzu       gas        std
# 45           0                 ?          isuzu       gas        std
# ...

# %%
data=data.drop("normalized-losses",axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
list1=["make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","fuel-system"]

# %%
le=LabelEncoder()

# %%
for i in list1:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#      symboling  make  fuel-type  aspiration  num-of-doors  body-style  \
# 0            3     0          1           0             2           0
# 1            3     0          1           0             2           0
# 2            1     0          1           0             2           2
# 3            2     1          1           0             1           3
# 4            2     1          1           0             1           3
# ..         ...   ...        ...         ...           ...         ...
# 200         -1    21          1           0             1           3
# 201         -1    21          1           1             1           3
# 202         -1    21          1           0             1           3
# 203         -1    21          0           1             1           3
# 204         -1    21          1           1             1           3
#
#      drive-wheels  engine-location  wheel-base  length  ...  engine-size  \
# ...

# %%
data=data.drop("engine-location",axis=1)
data
# Out:
#      symboling  make  fuel-type  aspiration  num-of-doors  body-style  \
# 0            3     0          1           0             2           0
# 1            3     0          1           0             2           0
# 2            1     0          1           0             2           2
# 3            2     1          1           0             1           3
# 4            2     1          1           0             1           3
# ..         ...   ...        ...         ...           ...         ...
# 200         -1    21          1           0             1           3
# 201         -1    21          1           1             1           3
# 202         -1    21          1           0             1           3
# 203         -1    21          0           1             1           3
# 204         -1    21          1           1             1           3
#
#      drive-wheels  wheel-base  length  width  ...  engine-size  fuel-system  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   make               205 non-null    int64
#  2   fuel-type          205 non-null    int64
#  3   aspiration         205 non-null    int64
#  4   num-of-doors       205 non-null    int64
#  5   body-style         205 non-null    int64
#  6   drive-wheels       205 non-null    int64
#  7   wheel-base         205 non-null    float64
#  8   length             205 non-null    float64
#  9   width              205 non-null    float64
#  10  height             205 non-null    float64
#  11  curb-weight        205 non-null    int64
#  12  engine-type        205 non-null    object
#  13  num-of-cylinders   205 non-null    object
#  14  engine-size        205 non-null    int64
#  15  fuel-system        205 non-null    int64
# ...

# %%
list1=['symboling', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
       'body-style', 'drive-wheels', 'wheel-base', 'length', 'width', 'height',
       'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
       'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
       'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
for i in list1:
    data[i]=le.fit_transform(data[i])
data
# Out:
#      symboling  make  fuel-type  aspiration  num-of-doors  body-style  \
# 0            5     0          1           0             2           0
# 1            5     0          1           0             2           0
# 2            3     0          1           0             2           2
# 3            4     1          1           0             1           3
# 4            4     1          1           0             1           3
# ..         ...   ...        ...         ...           ...         ...
# 200          1    21          1           0             1           3
# 201          1    21          1           1             1           3
# 202          1    21          1           0             1           3
# 203          1    21          0           1             1           3
# 204          1    21          1           1             1           3
#
#      drive-wheels  wheel-base  length  width  ...  engine-size  fuel-system  \
# ...

# %%
y=data["price"]

# %%
X=data.drop("price",axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_train.shape,X_test.shape
# Out:
# ((164, 23), (41, 23))

# %%
# Linear regression model 
from sklearn.linear_model import LinearRegression

# instantiate the model
lr = LinearRegression()
# fit the model 
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#predicting the target value from the model for the samples
y_test_lr = lr.predict(X_test)
y_train_lr = lr.predict(X_train)

# %%
#importing required libraries 
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
#computing the accuracy of the model performance
acc_train_lr = lr.score(X_train, y_train)
acc_test_lr = lr.score(X_test, y_test)

#computing root mean squared error (RMSE)
rmse_train_lr = np.sqrt(mean_squared_error(y_train, y_train_lr))
rmse_test_lr = np.sqrt(mean_squared_error(y_test, y_test_lr))

print("Linear Regression: Accuracy on training Data: {:.3f}".format(acc_train_lr))
print("Linear Regression: Accuracy on test Data: {:.3f}".format(acc_test_lr))
print('\nLinear Regression: The RMSE of the training set is:', rmse_train_lr)
print('Linear Regression: The RMSE of the testing set is:', rmse_test_lr)
# Out:
# Linear Regression: Accuracy on training Data: 0.425
# Linear Regression: Accuracy on test Data: 0.127
#
# Linear Regression: The RMSE of the training set is: 40.489497605599915
# Linear Regression: The RMSE of the testing set is: 54.12421463530555

# %%
plt.scatter(y_train,y_train_lr)

# %%
plt.scatter(y_test,y_test_lr)

# %%
#Scatter matrix for checking outlier
from pandas.plotting import scatter_matrix
plt.figure(figsize=(20,10))
attributes = ['symboling', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
       'body-style', 'drive-wheels', 'wheel-base'] 
scatter_matrix(data[attributes], figsize=(20,10))
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5,8))
sns.barplot(x = 'aspiration', y = "price", data = data)
plt.title('Suicide Count-Gender Bar Plot')
plt.show()
