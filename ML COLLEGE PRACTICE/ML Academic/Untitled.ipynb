# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("temperatures.csv")

# %%
data.shape
# Out:
# (117, 18)

# %%
data.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
data.describe().T
# Out:
#          count         mean        std      min      25%      50%      75%  \
# YEAR     117.0  1959.000000  33.919021  1901.00  1930.00  1959.00  1988.00
# JAN      117.0    23.687436   0.834588    22.00    23.10    23.68    24.18
# FEB      117.0    25.597863   1.150757    22.83    24.78    25.48    26.31
# MAR      117.0    29.085983   1.068451    26.68    28.37    29.04    29.61
# APR      117.0    31.975812   0.889478    30.01    31.46    31.95    32.42
# MAY      117.0    33.565299   0.724905    31.93    33.11    33.51    34.03
# JUN      117.0    32.774274   0.633132    31.10    32.34    32.73    33.18
# JUL      117.0    31.035897   0.468818    29.76    30.74    31.00    31.33
# AUG      117.0    30.507692   0.476312    29.31    30.18    30.54    30.76
# SEP      117.0    30.486752   0.544295    29.07    30.12    30.52    30.81
# OCT      117.0    29.766581   0.705492    27.90    29.38    29.78    30.17
# ...

# %%
data.isna().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
x = data["YEAR"]
plt.plot(data["YEAR"],data.iloc[:,1:13]);
plt.legend(["Jan","Feb","March","April","may","june","july","aug","sept","oct","nov","dec"])
plt.xlabel("year")
plt.ylabel("tempare range")
plt.title("Tempare")
# Out:
# Text(0.5, 1.0, 'Tempare')

# %%
data.dtypes
# Out:
# Age            int64
# Sex            int64
# ChestPain     object
# RestBP         int64
# Chol           int64
# Fbs            int64
# RestECG        int64
# MaxHR          int64
# ExAng          int64
# Oldpeak      float64
# Slope          int64
# Ca           float64
# Thal          object
# AHD           object
# dtype: object

# %%
data = data.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5688/880919259.py in <module>
# ----> 1 data = data.astype(float)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
data.dtypes
# Out:
# Age            int64
# Sex          float64
# ChestPain     object
# RestBP         int64
# Chol           int64
# Fbs            int64
# RestECG        int64
# MaxHR          int64
# ExAng          int64
# Oldpeak      float64
# Slope          int64
# Ca           float64
# Thal          object
# AHD           object
# dtype: object

# %%
data.nunique()
# Out:
# Age           41
# Sex            2
# ChestPain      4
# RestBP        50
# Chol         152
# Fbs            2
# RestECG        3
# MaxHR         91
# ExAng          2
# Oldpeak       40
# Slope          3
# Ca             4
# Thal           3
# AHD            2
# dtype: int64

# %%
data.Age.mean()
# Out:
# 54.43894389438944

# %%
df = data[["Age","Sex","ChestPain","RestBP"]]

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP
# 0     63  1.0       typical     145
# 1     67  1.0  asymptomatic     160
# 2     67  1.0  asymptomatic     120
# 3     37  1.0    nonanginal     130
# 4     41  0.0    nontypical     130
# ..   ...  ...           ...     ...
# 298   45  1.0       typical     110
# 299   68  1.0  asymptomatic     144
# 300   57  1.0  asymptomatic     130
# 301   57  0.0    nontypical     130
# 302   38  1.0    nonanginal     138
#
# [303 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest = train_test_split(df,test_size=0.25)

# %%
xtrain.shape,xtest.shape
# Out:
# ((227, 4), (76, 4))

# %%
from sklearn.preprocessing import LabelEncoder
